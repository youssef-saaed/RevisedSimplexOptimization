# %%
from scipy.optimize import linprog

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
c = [-2, -3]
A_ub , b_ub = [[2, 1], [1, 2]] , [4, 5]
A_eq , b_eq = None , None
bounds = [(0, None), (0, None)]
res = linprog(c, A_ub=A_ub, b_ub=b_ub, bounds=bounds, method='revised simplex')
print(f"Optimal solution: {res.x}\n Optimal value: {res.fun}")
# Out:
# Optimal solution: [1. 2.]
#  Optimal value: -8.0
# <ipython-input-4-2a12f1efe29a>:5: DeprecationWarning: `method='revised simplex'` is deprecated and will be removed in SciPy 1.11.0. Please use one of the HiGHS solvers (e.g. `method='highs'`) in new code.
#   res = linprog(c, A_ub=A_ub, b_ub=b_ub, bounds=bounds, method='revised simplex')

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
c = [-5, -4]
A_ub , b_ub = [[6, 4], [1, 2], [0, 1], [-1, 1]] , [24, 6, 2, 1]
A_eq , b_eq = None , None
bounds = [(0, None), (0, None)]
res = linprog(c, A_ub=A_ub, b_ub=b_ub, bounds=bounds, method='revised simplex')

print(f"Optimal solution: {res.x}\n Optimal value: {res.fun}")
# Out:
# Optimal solution:
# [3.  1.5]
# Optimal value:
# -21.0
# <ipython-input-5-adf53cdcb5c6>:22: DeprecationWarning: `method='revised simplex'` is deprecated and will be removed in SciPy 1.11.0. Please use one of the HiGHS solvers (e.g. `method='highs'`) in new code.
#   res = linprog(c, A_ub=A_ub, b_ub=b_ub, bounds=bounds, method='revised simplex')
